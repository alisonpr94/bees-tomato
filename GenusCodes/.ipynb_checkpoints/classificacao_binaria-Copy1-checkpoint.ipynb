# %%
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/home/alison/Documentos/Projeto-Tomate/datasets_generos/dataset_genero_mfcc.csv', sep=',')
df
# Out:
#        filename       mfcc1      mfcc2      mfcc3      mfcc4      mfcc5  \
# 0        10.WAV -187.834915  49.854252  -6.525051   4.707772   1.334116
# 1        10.WAV -211.676758  48.164745  -1.568784   3.710127  -3.730522
# 2        10.WAV -232.696899  81.410210  37.018658  20.403471  16.442812
# 3        91.WAV -185.587082  73.079796   8.960753  14.774915   6.392628
# 4        79.WAV -176.042435  23.128117   1.009835   1.976837  10.874933
# ..          ...         ...        ...        ...        ...        ...
# 319      77.WAV -193.445633  70.397263  24.390829  13.068544   9.895904
# 320  AU_106.WAV -201.261856  26.045488   9.252121  -4.036711  12.334292
# 321  AU_106.WAV -212.668457  60.251362  27.546824  19.377586   6.591743
# 322  AU_106.WAV -218.077881  50.708431  21.262539  18.374937   2.894032
# 323  AU_106.WAV  -94.651634  74.148613  24.932829  15.961182  16.095304
#
#          mfcc6      mfcc7     mfcc8     mfcc9  ...    mfcc33    mfcc34  \
# 0     1.693677   6.264961  2.519773  1.206058  ...  0.444205  2.252861
# 1    -3.279997  -0.343598 -0.073257  0.746383  ... -1.024178 -0.240914
# 2    14.575477  11.206918  6.474152  6.047267  ...  1.250340  0.958684
# 3    13.652942  10.269503  3.991142  4.798811  ... -1.759427 -1.076507
# 4     2.448837   9.874375 -8.328090 -2.791790  ... -3.763915  0.442332
# ..         ...        ...       ...       ...  ...       ...       ...
# 319   0.157841   6.059383  4.107074  2.891763  ... -0.253010  0.996578
# 320  13.763685  11.067427  7.608007  8.835520  ... -1.120433  0.002860
# 321   9.487063   7.369386  1.021628  6.468704  ... -1.433660 -0.849459
# 322  12.522385   8.673994  3.517556  9.766381  ... -1.557753 -0.758125
# 323  14.278756   7.963769  5.271248  1.261266  ...  0.094855  0.750209
#
#        mfcc35    mfcc36    mfcc37    mfcc38    mfcc39    mfcc40    Annotation  \
# 0    0.985763  1.885565 -0.026572 -0.801063 -0.571089 -0.822223  vibra_flor_1
# 1   -0.574752 -0.193956 -0.603252  0.036737 -0.689467  0.040395  vibra_flor_1
# 2   -0.131907 -0.131134 -0.765925 -0.879593 -0.483463 -0.753808           voo
# 3   -2.575743 -1.058758 -0.872088  0.383461  0.684918  0.585753  vibra_flor_1
# 4    0.830214  2.513018  0.919942  0.308315 -0.851657 -1.359397  vibra_flor_1
# ..        ...       ...       ...       ...       ...       ...           ...
# 319  0.913683  1.109603  0.823453  1.325328  0.529110  0.253913           voo
# 320 -0.711716  0.539241  0.596157  0.244936  0.366963 -0.075354  vibra_flor_1
# 321 -1.806133 -0.409997 -1.179835 -0.466693 -0.914471 -0.334721           voo
# 322 -1.410919  0.306396 -0.339728  0.648777 -0.101545  0.028543           voo
# 323 -0.361602  0.498804 -0.853159 -0.643610 -0.558632 -0.387093  vibra_flor_2
#
#               label
# 0    Augochloropsis
# 1    Augochloropsis
# 2    Augochloropsis
# 3    Augochloropsis
# 4    Augochloropsis
# ..              ...
# 319        Xylocopa
# 320        Xylocopa
# 321        Xylocopa
# 322        Xylocopa
# 323        Xylocopa
#
# [324 rows x 43 columns]

# %%
def modifica(label):
    if label != 'Exomalopsis':
        return "Others"
    else:
        return "Exomalopsis"
    
df.label = df.label.apply(modifica)
df
# Out:
#        filename       mfcc1      mfcc2      mfcc3      mfcc4      mfcc5  \
# 0        10.WAV -187.834915  49.854252  -6.525051   4.707772   1.334116
# 1        10.WAV -211.676758  48.164745  -1.568784   3.710127  -3.730522
# 2        10.WAV -232.696899  81.410210  37.018658  20.403471  16.442812
# 3        91.WAV -185.587082  73.079796   8.960753  14.774915   6.392628
# 4        79.WAV -176.042435  23.128117   1.009835   1.976837  10.874933
# ..          ...         ...        ...        ...        ...        ...
# 319      77.WAV -193.445633  70.397263  24.390829  13.068544   9.895904
# 320  AU_106.WAV -201.261856  26.045488   9.252121  -4.036711  12.334292
# 321  AU_106.WAV -212.668457  60.251362  27.546824  19.377586   6.591743
# 322  AU_106.WAV -218.077881  50.708431  21.262539  18.374937   2.894032
# 323  AU_106.WAV  -94.651634  74.148613  24.932829  15.961182  16.095304
#
#          mfcc6      mfcc7     mfcc8     mfcc9  ...    mfcc33    mfcc34  \
# 0     1.693677   6.264961  2.519773  1.206058  ...  0.444205  2.252861
# 1    -3.279997  -0.343598 -0.073257  0.746383  ... -1.024178 -0.240914
# 2    14.575477  11.206918  6.474152  6.047267  ...  1.250340  0.958684
# 3    13.652942  10.269503  3.991142  4.798811  ... -1.759427 -1.076507
# 4     2.448837   9.874375 -8.328090 -2.791790  ... -3.763915  0.442332
# ..         ...        ...       ...       ...  ...       ...       ...
# 319   0.157841   6.059383  4.107074  2.891763  ... -0.253010  0.996578
# 320  13.763685  11.067427  7.608007  8.835520  ... -1.120433  0.002860
# 321   9.487063   7.369386  1.021628  6.468704  ... -1.433660 -0.849459
# 322  12.522385   8.673994  3.517556  9.766381  ... -1.557753 -0.758125
# 323  14.278756   7.963769  5.271248  1.261266  ...  0.094855  0.750209
#
#        mfcc35    mfcc36    mfcc37    mfcc38    mfcc39    mfcc40    Annotation  \
# 0    0.985763  1.885565 -0.026572 -0.801063 -0.571089 -0.822223  vibra_flor_1
# 1   -0.574752 -0.193956 -0.603252  0.036737 -0.689467  0.040395  vibra_flor_1
# 2   -0.131907 -0.131134 -0.765925 -0.879593 -0.483463 -0.753808           voo
# 3   -2.575743 -1.058758 -0.872088  0.383461  0.684918  0.585753  vibra_flor_1
# 4    0.830214  2.513018  0.919942  0.308315 -0.851657 -1.359397  vibra_flor_1
# ..        ...       ...       ...       ...       ...       ...           ...
# 319  0.913683  1.109603  0.823453  1.325328  0.529110  0.253913           voo
# 320 -0.711716  0.539241  0.596157  0.244936  0.366963 -0.075354  vibra_flor_1
# 321 -1.806133 -0.409997 -1.179835 -0.466693 -0.914471 -0.334721           voo
# 322 -1.410919  0.306396 -0.339728  0.648777 -0.101545  0.028543           voo
# 323 -0.361602  0.498804 -0.853159 -0.643610 -0.558632 -0.387093  vibra_flor_2
#
#       label
# 0    Others
# 1    Others
# 2    Others
# 3    Others
# 4    Others
# ..      ...
# 319  Others
# 320  Others
# 321  Others
# 322  Others
# 323  Others
#
# [324 rows x 43 columns]

# %%
df.label.hist()

# %%
svm_param = [{'kernel': ['rbf'], 'gamma': [1e-2,1e-3,1e-4], 'C': [0.001, 0.1, 0.01, 1, 10], 'decision_function_shape': ['ovo']},
            {'kernel': ['poly'], 'gamma': [1e-2,1e-3,1e-4], 'C': [0.001, 0.1, 0.01, 1, 10], 'decision_function_shape': ['ovo']},
            {'kernel': ['sigmoid'], 'gamma': [1e-2,1e-3,1e-4], 'C': [0.001, 0.1, 0.01, 1, 10], 'decision_function_shape': ['ovo']}, 
            {'kernel': ['linear'], 'C': [0.001, 0.1, 0.01, 1, 10], 'decision_function_shape': ['ovo']}]

lr_param = [{'penalty': ['l1', 'l2']},
            {'C': [0.001, 0.1, 1, 10, 100]}]

rf_param = {'n_estimators': [100, 200],
            'max_features': ['auto', 'sqrt', 'log2']}

dtree_param = {"criterion": ["gini", "entropy"],
                "min_samples_split": [2, 10],
                "max_depth": [2, 5, 10]}

ens_param = {'lr__C': [0.001, 0.1, 1, 10, 100],
             'svc__C': [0.001, 0.1, 0.01, 1, 10]}

# %%
def grid_search(X_train, y_train, model, param):   
    kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)

    clf = GridSearchCV(model, param, scoring='f1_macro', cv=kfold)

    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    
    return clf.best_params_

# %%
def metricas(X_test, y_test, clf):
    y_true, y_pred = y_test, clf.predict(X_test)
    
    print("Acurácia...: %.4f" %(metrics.accuracy_score(y_true, y_pred) * 100))
    print("Precision..: %.4f" %(metrics.precision_score(y_true, y_pred, average='macro') * 100))
    print("Recall.....: %.4f" %(metrics.recall_score(y_true, y_pred, average='macro') * 100))
    print("F1-Score...: %.4f" %(metrics.f1_score(y_true, y_pred, average='macro') * 100))
    print()
    print(metrics.classification_report(y_true, y_pred))
    print()
    print(pd.crosstab(y_true, y_pred, rownames=['True'], colnames=['Predicted'], margins=True))
    
    #metrics.plot_roc_curve(clf, X_test, y_test)  
    #plt.show()
    #fig = plt.figure(num=None, figsize=(5, 5), dpi=80, facecolor='w', edgecolor='k')
    #tab_acertos = sns.heatmap(pd.crosstab(y_true, y_pred, rownames=['True'], colnames=['Predicted'], margins=True), 
    #    cmap="YlGnBu", annot=True, annot_kws={'size':14}, cbar=False, square=True)
    #tab_acertos.set_xticklabels(tab_acertos.get_xticklabels(), rotation=45) 
    #tab_acertos.get_figure().savefig('heatmap.jpeg')
    #plt.show()

# %%
def tipo_classificacao(df, buzz):
    if buzz == "flight":
        df = df[df['Annotation'] == 'voo']
    if buzz == "sonication":
        df = df[df['Annotation'] != 'voo']

    df = df.drop(['filename', 'Annotation'],axis=1)

    especies_list = df.iloc[:, -1]
    #encoder = LabelEncoder()
    #classes = encoder.fit_transform(especies_list)
    standard = StandardScaler()
    matriz = standard.fit_transform(np.array(df.iloc[:, :-1]))
    
    return matriz, especies_list

# %%
matrix_voo, classes_voo   = tipo_classificacao(df, "flight")
matrix_son, classes_son   = tipo_classificacao(df, "sonication")
matrix_both, classes_both = tipo_classificacao(df, "both")

# %% [markdown]
# ### Flight Classification

# %%
X_train_voo, X_test_voo, y_train_voo, y_test_voo = train_test_split(matrix_voo, classes_voo, test_size=0.5, random_state=0)

# %%
lr_modelo = LogisticRegression()
svm_modelo = SVC()
rf_modelo = RandomForestClassifier()
dtree_modelo = DecisionTreeClassifier()

svc = SVC()
rf = RandomForestClassifier()
lr = LogisticRegression()

modelos = [('svc', svc), ('rf', rf), ('lr', lr)]

ens_modelo = VotingClassifier(estimators=modelos, voting='hard')

# %%
best_param_lr = grid_search(X_train_voo, y_train_voo, lr_modelo, lr_param)
best_param_svm = grid_search(X_train_voo, y_train_voo, svm_modelo, svm_param)
best_param_rf = grid_search(X_train_voo, y_train_voo, rf_modelo, rf_param)
best_param_dtree = grid_search(X_train_voo, y_train_voo, dtree_modelo, dtree_param)
best_param_ens = grid_search(X_train_voo, y_train_voo, ens_modelo, ens_param)
# Out:
# Best parameters set found on development set:
#
# {'penalty': 'l2'}
# Best parameters set found on development set:
#
# {'C': 10, 'decision_function_shape': 'ovo', 'gamma': 0.01, 'kernel': 'rbf'}
# Best parameters set found on development set:
#
# {'max_features': 'sqrt', 'n_estimators': 100}
# Best parameters set found on development set:
#
# {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2}
# Best parameters set found on development set:
#
# {'lr__C': 1, 'svc__C': 1}

# %%
def treino_teste(X_train, X_test, y_train, y_test, best_param_lr, best_param_svm, best_param_rf, best_param_dtree,
                best_param_ens):
    
    print("--------------------- Logistic Regression ---------------------")
    print()
    
    if list(best_param_lr.keys())[0] == 'C':
        lr_model = LogisticRegression(C=best_param_lr['C'])
    else:
        lr_model = LogisticRegression(penalty=best_param_lr['penalty'])

    lr_model.fit(X_train, y_train)

    y_pred = lr_model.predict(X_test)

    metricas(X_test, y_test, lr_model)
    print()
    
    print("--------------------- Support Vector Machine ---------------------")
    print()
    svm_model = SVC(C=best_param_svm['C'], decision_function_shape=best_param_svm['decision_function_shape'], 
                    gamma=best_param_svm['gamma'], kernel=best_param_svm['kernel'])

    svm_model.fit(X_train, y_train)

    y_pred = svm_model.predict(X_test)

    metricas(X_test, y_test, svm_model)
    print()
    
    print("--------------------- Random Forest ---------------------")
    print()
    rf_model = RandomForestClassifier(max_features=best_param_rf['max_features'], n_estimators=best_param_rf['n_estimators'])

    rf_model.fit(X_train, y_train)

    y_pred = rf_model.predict(X_test)
    
    metricas(X_test, y_test, rf_model)
    print()
    
    print("--------------------- Decision Tree ---------------------")
    print()
    dtree_model = DecisionTreeClassifier(criterion=best_param_dtree['criterion'], 
                                         max_depth=best_param_dtree['max_depth'], 
                                         min_samples_split=best_param_dtree['min_samples_split'])

    dtree_model.fit(X_train, y_train)

    y_pred = dtree_model.predict(X_test)

    metricas(X_test, y_test, dtree_model)
    print()
    
    print("--------------------- Ensemble ---------------------")
    print()
    svc = SVC(C=best_param_ens['svc__C'])
    rf = RandomForestClassifier()
    lr = LogisticRegression(C=best_param_ens['lr__C'])

    modelos = [('svc', svc), ('rf', rf), ('lr', lr)]

    ens_model = VotingClassifier(estimators=modelos, voting='hard')

    ens_model.fit(X_train, y_train)

    y_pred = ens_model.predict(X_test)

    metricas(X_test, y_test, ens_model)
    print()
    
    print("--------------------- Curva ROC ---------------------")
    print()
    fig, ax = plt.subplots()

    models = [
        ("LR", lr_model),
        ("SVM", svm_model),
        ("RF", rf_model),
        ("DTree", dtree_model),
        #("Ensemble", ens_model),
    ]

    model_displays = {}
    for name, pipeline in models:
        model_displays[name] = metrics.plot_roc_curve(pipeline, X_test, y_test, ax=ax, name=name)
    _ = ax.set_title('ROC curve')

# %%
print("Resultados fligh classification")
print()

treino_teste(X_train_voo, X_test_voo, y_train_voo, y_test_voo, best_param_lr, best_param_svm, best_param_rf, best_param_dtree,
            best_param_ens)
# Out:
# Resultados fligh classification
#
# --------------------- Logistic Regression ---------------------
#
# Acurácia...: 83.0189
# Precision..: 63.7500
# Recall.....: 59.1667
# F1-Score...: 60.5459
#
#               precision    recall  f1-score   support
#
#  Exomalopsis       0.40      0.25      0.31         8
#       Others       0.88      0.93      0.90        45
#
#     accuracy                           0.83        53
#    macro avg       0.64      0.59      0.61        53
# weighted avg       0.80      0.83      0.81        53
#
#
# Predicted    Exomalopsis  Others  All
# True
# Exomalopsis            2       6    8
# Others                 3      42   45
# All                    5      48   53
#
# --------------------- Support Vector Machine ---------------------
#
# Acurácia...: 86.7925
# Precision..: 74.7917
# Recall.....: 66.5278
# F1-Score...: 69.3135
#
#               precision    recall  f1-score   support
#
#  Exomalopsis       0.60      0.38      0.46         8
#       Others       0.90      0.96      0.92        45
#
#     accuracy                           0.87        53
#    macro avg       0.75      0.67      0.69        53
# weighted avg       0.85      0.87      0.85        53
#
#
# Predicted    Exomalopsis  Others  All
# True
# Exomalopsis            3       5    8
# Others                 2      43   45
# All                    5      48   53
#
# --------------------- Random Forest ---------------------
#
# Acurácia...: 81.1321
# Precision..: 55.3571
# Recall.....: 52.9167
# F1-Score...: 53.0142
#
#               precision    recall  f1-score   support
#
#  Exomalopsis       0.25      0.12      0.17         8
#       Others       0.86      0.93      0.89        45
#
#     accuracy                           0.81        53
#    macro avg       0.55      0.53      0.53        53
# weighted avg       0.77      0.81      0.78        53
#
#
# Predicted    Exomalopsis  Others  All
# True
# Exomalopsis            1       7    8
# Others                 3      42   45
# All                    4      49   53
#
# --------------------- Decision Tree ---------------------
#
# Acurácia...: 79.2453
# Precision..: 60.9848
# Recall.....: 62.0833
# F1-Score...: 61.4673
#
#               precision    recall  f1-score   support
#
#  Exomalopsis       0.33      0.38      0.35         8
#       Others       0.89      0.87      0.88        45
#
#     accuracy                           0.79        53
#    macro avg       0.61      0.62      0.61        53
# weighted avg       0.80      0.79      0.80        53
#
#
# Predicted    Exomalopsis  Others  All
# True
# Exomalopsis            3       5    8
# Others                 6      39   45
# All                    9      44   53
#
# --------------------- Ensemble ---------------------
#
# Acurácia...: 84.9057
# Precision..: 68.8776
# Recall.....: 60.2778
# F1-Score...: 62.4113
#
#               precision    recall  f1-score   support
#
#  Exomalopsis       0.50      0.25      0.33         8
#       Others       0.88      0.96      0.91        45
#
#     accuracy                           0.85        53
#    macro avg       0.69      0.60      0.62        53
# weighted avg       0.82      0.85      0.83        53
#
#
# Predicted    Exomalopsis  Others  All
# True
# Exomalopsis            2       6    8
# Others                 2      43   45
# All                    4      49   53
#
# --------------------- Curva ROC ---------------------

# %% [markdown]
# ### Sonication Classification

# %%
X_train_son, X_test_son, y_train_son, y_test_son = train_test_split(matrix_son, classes_son, test_size=0.5, random_state=0)

# %%
best_param_lr = grid_search(X_train_son, y_train_son, lr_modelo, lr_param)
best_param_svm = grid_search(X_train_son, y_train_son, svm_modelo, svm_param)
best_param_rf = grid_search(X_train_son, y_train_son, rf_modelo, rf_param)
best_param_dtree = grid_search(X_train_son, y_train_son, dtree_modelo, dtree_param)
best_param_ens = grid_search(X_train_son, y_train_son, ens_modelo, ens_param)
# Out:
# Best parameters set found on development set:
#
# {'penalty': 'l2'}
# Best parameters set found on development set:
#
# {'C': 10, 'decision_function_shape': 'ovo', 'gamma': 0.01, 'kernel': 'rbf'}
# Best parameters set found on development set:
#
# {'max_features': 'log2', 'n_estimators': 200}
# Best parameters set found on development set:
#
# {'criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 2}
# Best parameters set found on development set:
#
# {'lr__C': 10, 'svc__C': 10}

# %%
print("Resultados sonication classification")
print()

treino_teste(X_train_son, X_test_son, y_train_son, y_test_son, best_param_lr, best_param_svm, best_param_rf, best_param_dtree,
            best_param_ens)
# Out:
# Resultados sonication classification
#
# --------------------- Logistic Regression ---------------------
#
# Acurácia...: 80.9091
# Precision..: 78.8552
# Recall.....: 79.2032
# F1-Score...: 79.0210
#
#               precision    recall  f1-score   support
#
#  Exomalopsis       0.72      0.74      0.73        38
#       Others       0.86      0.85      0.85        72
#
#     accuracy                           0.81       110
#    macro avg       0.79      0.79      0.79       110
# weighted avg       0.81      0.81      0.81       110
#
#
# Predicted    Exomalopsis  Others  All
# True
# Exomalopsis           28      10   38
# Others                11      61   72
# All                   39      71  110
#
# --------------------- Support Vector Machine ---------------------
#
# Acurácia...: 84.5455
# Precision..: 82.7324
# Recall.....: 83.8450
# F1-Score...: 83.2121
#
#               precision    recall  f1-score   support
#
#  Exomalopsis       0.76      0.82      0.78        38
#       Others       0.90      0.86      0.88        72
#
#     accuracy                           0.85       110
#    macro avg       0.83      0.84      0.83       110
# weighted avg       0.85      0.85      0.85       110
#
#
# Predicted    Exomalopsis  Others  All
# True
# Exomalopsis           31       7   38
# Others                10      62   72
# All                   41      69  110
#
# --------------------- Random Forest ---------------------
#
# Acurácia...: 88.1818
# Precision..: 86.6207
# Recall.....: 87.8655
# F1-Score...: 87.1622
#
#               precision    recall  f1-score   support
#
#  Exomalopsis       0.80      0.87      0.84        38
#       Others       0.93      0.89      0.91        72
#
#     accuracy                           0.88       110
#    macro avg       0.87      0.88      0.87       110
# weighted avg       0.89      0.88      0.88       110
#
#
# Predicted    Exomalopsis  Others  All
# True
# Exomalopsis           33       5   38
# Others                 8      64   72
# All                   41      69  110
#
# --------------------- Decision Tree ---------------------
#
# Acurácia...: 77.2727
# Precision..: 74.9558
# Recall.....: 75.8041
# F1-Score...: 75.3120
#
#               precision    recall  f1-score   support
#
#  Exomalopsis       0.66      0.71      0.68        38
#       Others       0.84      0.81      0.82        72
#
#     accuracy                           0.77       110
#    macro avg       0.75      0.76      0.75       110
# weighted avg       0.78      0.77      0.77       110
#
#
# Predicted    Exomalopsis  Others  All
# True
# Exomalopsis           27      11   38
# Others                14      58   72
# All                   41      69  110
#
# --------------------- Ensemble ---------------------
#
# Acurácia...: 86.3636
# Precision..: 84.6766
# Recall.....: 85.8553
# F1-Score...: 85.1872
#
#               precision    recall  f1-score   support
#
#  Exomalopsis       0.78      0.84      0.81        38
#       Others       0.91      0.88      0.89        72
#
#     accuracy                           0.86       110
#    macro avg       0.85      0.86      0.85       110
# weighted avg       0.87      0.86      0.86       110
#
#
# Predicted    Exomalopsis  Others  All
# True
# Exomalopsis           32       6   38
# Others                 9      63   72
# All                   41      69  110
#
# --------------------- Curva ROC ---------------------

# %% [markdown]
# ### Flight + Sonication Classification

# %%
X_train_both, X_test_both, y_train_both, y_test_both = train_test_split(matrix_both, classes_both, test_size=0.5, random_state=0)

# %%
best_param_lr = grid_search(X_train_both, y_train_both, lr_modelo, lr_param)
best_param_svm = grid_search(X_train_both, y_train_both, svm_modelo, svm_param)
best_param_rf = grid_search(X_train_both, y_train_both, rf_modelo, rf_param)
best_param_dtree = grid_search(X_train_both, y_train_both, dtree_modelo, dtree_param)
best_param_ens = grid_search(X_train_both, y_train_both, ens_modelo, ens_param)
# Out:
# Best parameters set found on development set:
#
# {'penalty': 'l2'}
# Best parameters set found on development set:
#
# {'C': 10, 'decision_function_shape': 'ovo', 'gamma': 0.01, 'kernel': 'rbf'}
# Best parameters set found on development set:
#
# {'max_features': 'auto', 'n_estimators': 200}
# Best parameters set found on development set:
#
# {'criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 10}
# Best parameters set found on development set:
#
# {'lr__C': 100, 'svc__C': 1}

# %%
print("Resultados flight + sonication classification")
print()

treino_teste(X_train_both, X_test_both, y_train_both, y_test_both, best_param_lr, best_param_svm, best_param_rf, best_param_dtree,
            best_param_ens)
# Out:
# Resultados flight + sonication classification
#
# --------------------- Logistic Regression ---------------------
#
# Acurácia...: 79.6296
# Precision..: 77.0833
# Recall.....: 75.6535
# F1-Score...: 76.2643
#
#               precision    recall  f1-score   support
#
#  Exomalopsis       0.71      0.64      0.67        53
#       Others       0.83      0.87      0.85       109
#
#     accuracy                           0.80       162
#    macro avg       0.77      0.76      0.76       162
# weighted avg       0.79      0.80      0.79       162
#
#
# Predicted    Exomalopsis  Others  All
# True
# Exomalopsis           34      19   53
# Others                14      95  109
# All                   48     114  162
#
# --------------------- Support Vector Machine ---------------------
#
# Acurácia...: 85.8025
# Precision..: 85.7738
# Recall.....: 81.2100
# F1-Score...: 82.8729
#
#               precision    recall  f1-score   support
#
#  Exomalopsis       0.86      0.68      0.76        53
#       Others       0.86      0.94      0.90       109
#
#     accuracy                           0.86       162
#    macro avg       0.86      0.81      0.83       162
# weighted avg       0.86      0.86      0.85       162
#
#
# Predicted    Exomalopsis  Others  All
# True
# Exomalopsis           36      17   53
# Others                 6     103  109
# All                   42     120  162
#
# --------------------- Random Forest ---------------------
#
# Acurácia...: 79.0123
# Precision..: 78.3352
# Recall.....: 71.8020
# F1-Score...: 73.4784
#
#               precision    recall  f1-score   support
#
#  Exomalopsis       0.77      0.51      0.61        53
#       Others       0.80      0.93      0.86       109
#
#     accuracy                           0.79       162
#    macro avg       0.78      0.72      0.73       162
# weighted avg       0.79      0.79      0.78       162
#
#
# Predicted    Exomalopsis  Others  All
# True
# Exomalopsis           27      26   53
# Others                 8     101  109
# All                   35     127  162
#
# --------------------- Decision Tree ---------------------
#
# Acurácia...: 72.2222
# Precision..: 68.1409
# Recall.....: 66.7561
# F1-Score...: 67.2727
#
#               precision    recall  f1-score   support
#
#  Exomalopsis       0.59      0.51      0.55        53
#       Others       0.78      0.83      0.80       109
#
#     accuracy                           0.72       162
#    macro avg       0.68      0.67      0.67       162
# weighted avg       0.71      0.72      0.72       162
#
#
# Predicted    Exomalopsis  Others  All
# True
# Exomalopsis           27      26   53
# Others                19      90  109
# All                   46     116  162
#
# --------------------- Ensemble ---------------------
#
# Acurácia...: 81.4815
# Precision..: 81.3405
# Recall.....: 75.0909
# F1-Score...: 76.9231
#
#               precision    recall  f1-score   support
#
#  Exomalopsis       0.81      0.57      0.67        53
#       Others       0.82      0.94      0.87       109
#
#     accuracy                           0.81       162
#    macro avg       0.81      0.75      0.77       162
# weighted avg       0.81      0.81      0.80       162
#
#
# Predicted    Exomalopsis  Others  All
# True
# Exomalopsis           30      23   53
# Others                 7     102  109
# All                   37     125  162
#
# --------------------- Curva ROC ---------------------
